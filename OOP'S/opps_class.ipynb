# %%
class student:
    def __init__ (self,name,age,gender,course):
        self.name=name
        self.age=age
        self.gender=gender
        self.course=course
    def info(self,hobby,place): 
        return f"{self.name} His/Her Age is {self.age} year old's.\nGender is {self.gender}..\nHis/Her learning {self.course}.\nHobby is {hobby}.\nHis/Her living in {place}.\n\n"

stn=student('Aishavarya','25','female','Data Science course')
print(stn.info('Reding','Airoli'))

stn=student('Aishavarya','25','female','Python course')
print(stn.info('Writing','Belapur'))

stn=student('Krutika','21','female','Python course')
print(stn.info('Crafting','Kalyan'))

stn=student('Dipika','24','female','Data Science course')
print(stn.info('Dancing','Kalyan'))

stn=student('Tushar','25','Male','Data Science course')
print(stn.info('Tracking','Kalyan'))

stn=student('Nikhil','23','Male','Data Science course')
print(stn.info('Collecting New info','Asangoan'))

stn=student('Vipin','30','Male','Python')
print(stn.info('Making Application','Thane'))

stn=student('kiran','25','Male','Python')
print(stn.info('Traveling','Asangoan'))

stn=student('Aniruddh','19','Male','Python course')
print(stn.info('Collecting New info','Ghansoli'))

stn=student('Tejas','25','Male','Python course')
print(stn.info('His love Singing','Thane'))
# Out:
# Aishavarya His/Her Age is 25 year old's.
# Gender is female..
# His/Her learning Data Science course.
# Hobby is Reding.
# His/Her living in Airoli.
#
#
# Aishavarya His/Her Age is 25 year old's.
# Gender is female..
# His/Her learning Python course.
# Hobby is Writing.
# His/Her living in Belapur.
#
#
# Krutika His/Her Age is 21 year old's.
# Gender is female..
# His/Her learning Python course.
# Hobby is Crafting.
# His/Her living in Kalyan.
#
#
# Dipika His/Her Age is 24 year old's.
# Gender is female..
# His/Her learning Data Science course.
# Hobby is Dancing.
# His/Her living in Kalyan.
#
#
# Tushar His/Her Age is 25 year old's.
# Gender is Male..
# His/Her learning Data Science course.
# Hobby is Tracking.
# His/Her living in Kalyan.
#
#
# Nikhil His/Her Age is 23 year old's.
# Gender is Male..
# His/Her learning Data Science course.
# Hobby is Collecting New info.
# His/Her living in Asangoan.
#
#
# Vipin His/Her Age is 30 year old's.
# Gender is Male..
# ...
